# %% [markdown]
# # 0. Import Data and Dependencies

# %% [markdown]
# ## 0.0 Dependencies

# %%
import pandas as pd
import numpy as np
import os
import gdown
import zipfile
import shutil
import re

# %% [markdown]
# ## 0.1 Extracting and Downloading Data

# %% [markdown]
# Paths

# %%
gdrive_url = 'https://drive.google.com/uc?id=1jmSta-CD03w341lOzNjT_1qAeNDt2zL2'
output_path = 'archive.zip'
output_folder_path = 'archive'
extract_to_folder = "c:\\temp_extract"

# %% [markdown]
# Extraction Functions

# %%
# function for extracting a zip file stored at a url

def extract_zip(zip_file_path, extract_to):
    # Extract the zip file if it exists and is valid 
    try:
        with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
            zip_ref.extractall(extract_to)
            print(f"Extracted all files to {extract_to}")
    except FileNotFoundError:
        print(f"Error: File {zip_file_path} does not exist.")
    except zipfile.BadZipFile:
        print("Error: Not a valid zip file.")
    except Exception as e:
        print(f"An error occured: {e}")
    

# function for downloading and extracting zip folder from gdrive link
def download_and_extract(gdrive_url, output_path, extract_to_folder, output_folder_path):
    # Download the file
    try: 
        gdown.download(gdrive_url, output_path, quiet=False)
        print(f'File downloaded and saved as {output_path}')
        # Extract the downloaded zip file
        extract_zip(output_path, extract_to_folder)
        # Move extracted folder and clean up
        shutil.move(extract_to_folder, output_folder_path)
        os.remove(output_path)
        print(f"Moved extracted files to {output_folder_path} and removed {output_path}")
    except Exception as e:
        print(f"An error occurred during the download or extraction process: {e}")

download_and_extract(gdrive_url, output_path, extract_to_folder, output_folder_path)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1jmSta-CD03w341lOzNjT_1qAeNDt2zL2
# From (redirected): https://drive.google.com/uc?id=1jmSta-CD03w341lOzNjT_1qAeNDt2zL2&confirm=t&uuid=4102c6f3-c50c-4a77-933a-98500c6488a8
# To: c:\Users\bened\DataScience\ANLP\AT2\36118_NLP_Spring\notebooks\archive.zip
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 689M/689M [01:15<00:00, 9.17MB/s]
# File downloaded and saved as archive.zip
#   3%|▎         | 18.4M/689M [1:17:37<47:18:35, 3.94kB/s]
#  30%|██▉       | 206M/689M [1:17:13<3:01:08, 44.5kB/s]
# Extracted all files to c:\temp_extract
# Moved extracted files to archive and removed archive.zip

# %%
# Define path for screenplay data
texts_path = os.path.join(output_folder_path, "screenplay_data", "data", "raw_texts", "raw_texts")

# Intialize a dictionary for storing file names and contents
screenplays = {}

# List and iterate over all files in the folder
for file_name in os.listdir(texts_path):
    file_path = os.path.join(texts_path, file_name)

    # Ensure the path is an actual file before reading
    if os.path.isfile(file_path):
        try:
            # Read and store file contents
            with open(file_path, 'r', encoding='utf-8') as f:
                screenplays[file_name] = f.read()
        except Exception as e:
            print(f"Error reading {file_name}: {e}")

# Print a sample of first ten files to check files have been parsed
for i, (file_name, content) in enumerate(screenplays.items()):
    if i == 10:
        break
    print(f"Example of {file_name}:\n")
    print(content[:100])
    print("-" * 50)
# Out:
# Error reading A Hard Days Night_0581729.txt: 'utf-8' codec can't decode byte 0xe9 in position 62670: invalid continuation byte
# Error reading An American Werewolf in Paris_0118604.txt: 'utf-8' codec can't decode byte 0xe9 in position 47384: invalid continuation byte
# Error reading At First Sight_0132512.txt: 'utf-8' codec can't decode byte 0x85 in position 2467: invalid start byte
# Error reading Batman Robin_0118688.txt: 'utf-8' codec can't decode byte 0x92 in position 5242: invalid start byte
# Error reading Body Bags_0106449.txt: 'utf-8' codec can't decode byte 0xa9 in position 45: invalid start byte
# Error reading Boy Who Never Slept_1781782.txt: 'utf-8' codec can't decode byte 0x85 in position 37957: invalid start byte
# Error reading Brazil_0088846.txt: 'utf-8' codec can't decode byte 0xa3 in position 30758: invalid start byte
# Error reading Erik the Viking_0097289.txt: 'utf-8' codec can't decode byte 0xe9 in position 157568: invalid continuation byte
# Error reading Exorcist The Beginning_0204313.txt: 'utf-8' codec can't decode byte 0x85 in position 55583: invalid start byte
# Error reading Get Shorty_5761496.txt: 'utf-8' codec can't decode byte 0x96 in position 496: invalid start byte
# Error reading Going for the Gold The Bill Johnson Story_0089212.txt: 'utf-8' codec can't decode byte 0x8d in position 1412: invalid start byte
# Error reading Halloween_0296665.txt: 'utf-8' codec can't decode byte 0x92 in position 289: invalid start byte
# Error reading Happiness_0147612.txt: 'utf-8' codec can't decode byte 0x85 in position 374: invalid start byte
# Error reading Jurassic Park III_0163025.txt: 'utf-8' codec can't decode byte 0x96 in position 145: invalid start byte
# Error reading L Avventura_0053619.txt: 'utf-8' codec can't decode byte 0x82 in position 112303: invalid start byte
# Error reading L on The Professional_0110413.txt: 'utf-8' codec can't decode byte 0x82 in position 113302: invalid start byte
# Error reading Lon_7663372.txt: 'utf-8' codec can't decode byte 0x82 in position 113302: invalid start byte
# Error reading MASH_0066026.txt: 'utf-8' codec can't decode byte 0x96 in position 473: invalid start byte
# Error reading Midnight Run_0095631.txt: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Error reading Nan quan wang_0110625.txt: 'utf-8' codec can't decode byte 0x85 in position 135629: invalid start byte
# Error reading Othello_0114057.txt: 'utf-8' codec can't decode byte 0xe8 in position 164: invalid continuation byte
# Error reading Planet of the Apes_0063442.txt: 'utf-8' codec can't decode byte 0xd5 in position 93285: invalid continuation byte
# Error reading Portrait of Jennie_0040705.txt: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Error reading Professional Theatre 2_12821228.txt: 'utf-8' codec can't decode byte 0x82 in position 113302: invalid start byte
# Error reading Pygmalion_0030637.txt: 'utf-8' codec can't decode byte 0x92 in position 1388: invalid start byte
# Error reading Ride the High Country_0056412.txt: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Error reading Salt of the Earth_0047443.txt: 'utf-8' codec can't decode byte 0xd3 in position 3587: invalid continuation byte
# Error reading Shine_0117631.txt: 'utf-8' codec can't decode byte 0x92 in position 349: invalid start byte
# Error reading Sitting Bull A Stone in My Heart_1493183.txt: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Error reading Smokey and the Bandit_0076729.txt: 'utf-8' codec can't decode byte 0xb0 in position 84290: invalid start byte
# Error reading Smoke_0114478.txt: 'utf-8' codec can't decode byte 0xe9 in position 2610: invalid continuation byte
# Error reading Southgate to Brighton_7547872.txt: 'utf-8' codec can't decode byte 0x82 in position 8253: invalid start byte
# Error reading Sperm The Motion Picture_1414273.txt: 'utf-8' codec can't decode byte 0xe9 in position 49978: invalid continuation byte
# Error reading Stagecoach_0031971.txt: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Error reading Superman III_0086393.txt: 'utf-8' codec can't decode byte 0xe9 in position 16387: invalid continuation byte
# Error reading Superman II_0081573.txt: 'utf-8' codec can't decode byte 0xe9 in position 110051: invalid continuation byte
# Error reading Superman IV The Quest for Peace_0094074.txt: 'utf-8' codec can't decode byte 0xef in position 26026: invalid continuation byte
# Error reading Superman_0078346.txt: 'utf-8' codec can't decode byte 0x82 in position 79680: invalid start byte
# Error reading The Adventures of Priscilla Queen of the Desert_0109045.txt: 'utf-8' codec can't decode byte 0x85 in position 1547: invalid start byte
# Error reading The Blue Hotel_0554018.txt: 'utf-8' codec can't decode byte 0xe7 in position 170332: invalid continuation byte
# Error reading The Corruptor_0142192.txt: 'utf-8' codec can't decode byte 0x92 in position 413: invalid start byte
# Error reading The Deep End of the Ocean_0120646.txt: 'utf-8' codec can't decode byte 0x82 in position 25936: invalid start byte
# Error reading The House Next Door_0286702.txt: 'utf-8' codec can't decode byte 0x93 in position 30: invalid start byte
# Error reading The Hustler_0054997.txt: 'utf-8' codec can't decode byte 0xe9 in position 386: invalid continuation byte
# Error reading The Ladykillers_0048281.txt: 'utf-8' codec can't decode byte 0x96 in position 41963: invalid start byte
# Error reading The Last Kiss Goodnight_0700739.txt: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Error reading The Lost Weekend_0037884.txt: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Error reading The Naked City_0040636.txt: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Error reading The Ninth Gate_0142688.txt: 'utf-8' codec can't decode byte 0x82 in position 8487: invalid start byte
# Error reading The Public Eye_0105187.txt: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Error reading The Wild One_0047677.txt: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Error reading Things to Come_0028358.txt: 'utf-8' codec can't decode byte 0xe9 in position 114023: invalid continuation byte
# Error reading THX 1138_0066434.txt: 'utf-8' codec can't decode byte 0xd2 in position 61131: invalid continuation byte
# Error reading Time to Hunt_11777040.txt: 'utf-8' codec can't decode byte 0xe7 in position 8576: invalid continuation byte
# Error reading Viridiana_0055601.txt: 'utf-8' codec can't decode byte 0xa5 in position 6936: invalid start byte
# Error reading Waking Up the Town_0016497.txt: 'utf-8' codec can't decode byte 0xa5 in position 6936: invalid start byte
# Error reading Waxwork_0096426.txt: 'utf-8' codec can't decode byte 0xe9 in position 23193: invalid continuation byte
# Error reading Who s Your Daddy_0287138.txt: 'utf-8' codec can't decode byte 0xe9 in position 417: invalid continuation byte
# Error reading Working Girl_0096463.txt: 'utf-8' codec can't decode byte 0xe9 in position 20481: invalid continuation byte
# Example of 10 Cloverfield Lane_1179933.txt:
#
# The Cellar
#
# by
# Josh Campbell & Matt Stuecken
# DARKNESS
#
# And then --
#
# A GUNNED ENGINE --
#
# BLURRED HEA
# --------------------------------------------------
# Example of 10 Things I Hate About You_0147800.txt:
#
#
#                                TEN THINGS I HATE ABOUT YOU
#
#                 written by Ka
# --------------------------------------------------
# Example of 101 Days of 101 Dalmatians_0249328.txt:
#
# 107
# #2
# 40] _DALMATIANS MARCH 17, 1995
#
# EXT. SKY. FULL MOON
#
# A huge, yellow moon. CAMERA TILTS DOWN
# --------------------------------------------------
# Example of 12 Angry Men_0118528.txt:
#
# PLEASE COPY AND RETURN |
#
# ———_————_
#
#
#
# TWELVE ANGRY MEN
#
# by Reginald Rose
#
# THE WRITING CREDITS MAY
# --------------------------------------------------
# Example of 12 Monkeys_0114746.txt:
#
#
# 				TWELVE MONKEYS
#
# 		          An original screenplay by
#
# 				David Peoples
#   				     &amp;
#
# --------------------------------------------------
# Example of 12 Years a Slave_2024544.txt:
#
#
#
#
#
#
#
#                              12 YEARS A SLAVE
#
#
#
#
#
#
#
#
#
#                                Written
# --------------------------------------------------
# Example of 127 Hours_1542344.txt:
#
#
#
#
#
#
#
#                                    127 HOURS
#
#
#
#
#
#
#
#                                    Writte
# --------------------------------------------------
# Example of 13 13 13_2991516.txt:
#
# 13/13/13
#
# Written by
#
# James Cullen Bressack
#
# 5/15/13
# TEASER
#
# FADE IN:
#
# WIDE-EXT. JACK’S HOUSE-AFTER
# --------------------------------------------------
# Example of 1408_0450385.txt:
#
# 1408
#
# Written by
# Scott Alexander & Larry Karaszewski
# * FADE IN:
#
# EXT. HIGHWAY -~ DAY
# A dull highway
# --------------------------------------------------
# Example of 1492 Conquest of Paradise_0103594.txt:
#
#
#
#
#
#                 1492: CONQUEST OF PARADISE
#
#
#                              by
#
#
# --------------------------------------------------

# %% [markdown]
# Download movie metadata and read into pandas DataFrame.

# %%
# Set display option for visibility
pd.set_option('display.max_columns', 25)

# Define path to the metadata CSV file
csv_path = os.path.join(output_folder_path, 'movie_metadata', 'movie_meta_data.csv')

# Ensure path exists before trying to read 
if os.path.exists(csv_path):
    # Read the CSV file into pandas datastructure
    meta_df = pd.read_csv(csv_path)
    # Print column names
    print(meta_df.columns)
    # Display first few rows of dataframe
    meta_df.head()
else:
    print(f"File {csv_path} does not exist.")
# Out:
# Index(['imdbid', 'title', 'akas', 'year', 'metascore', 'imdb user rating',
#        'number of imdb user votes', 'awards', 'opening weekend', 'producers',
#        'budget', 'script department', 'production companies', 'writers',
#        'directors', 'casting directors', 'cast', 'countries', 'age restrict',
#        'plot', 'plot outline', 'keywords', 'genres', 'taglines', 'synopsis'],
#       dtype='object')
#    imdbid                   title  \
# 0  120770  A Night at the Roxbury
# 1  132512          At First Sight
# 2  118661            The Avengers
# 3  215545              Bamboozled
# 4  118715        The Big Lebowski
#
#                                                 akas  year  metascore  \
# 0  Une nuit au Roxbury (France), Movida en el Rox...  1998         26
# 1  Sight Unseen (United States), Premier regard (...  1999         40
# 2  Chapeau melon et bottes de cuir (France), Mit ...  1998         12
# 3  The Very Black Show (France), It's Showtime (G...  2000         54
# 4  El gran Lebowski (Spain), O Grande Lebowski (P...  1998         71
#
#    imdb user rating  number of imdb user votes  \
# 0                 6                      56537
# 1                 6                      12922
# 2                 3                      40784
# 3                 6                      10373
# 4                 8                     724388
#
#                                               awards  \
# 0                                                NaN
# 1                                                NaN
# 2  FMCJ Award 1998, Golden Reel Award 1999, Razzi...
# 3  Golden Berlin Bear 2001, Black Reel 2001, Imag...
# 4  Honorable Mention 1998, ACCA 1998, Golden Berl...
#
#                            opening weekend  \
# 0                          United States:
# 1                          United States:
# 2  United States: $10,305,957, 16 Aug 1998
# 3                          United States:
# 4   United States: $5,533,844, 08 Mar 1998
#
#                                            producers                   budget  \
# 0  Marie Cantin, Erin Fraser, Amy Heckerling, Ste...  $17,000,000 (estimated)
# 1           Rob Cowan, Roger Paradiso, Irwin Winkler  $60,000,000 (estimated)
# 2                       Susan Ekins, Jerry Weintraub  $60,000,000 (estimated)
# 3          Jon Kilik, Spike Lee, Kisha Imani Cameron  $10,000,000 (estimated)
# 4  Tim Bevan, John Cameron, Ethan Coen, Eric Fell...  $15,000,000 (estimated)
#
#                       script department  \
# 0                                   NaN
# 1                                   NaN
# 2         Sharon Mansfield, Anna Worley
# 3  Shari L. Carpenter, Carolyn De Sousa
# 4                         T. Kukovinski
#
#                                 production companies  \
# 0  Broadway Pictures, Paramount Pictures, SNL Stu...
# 1                                Metro-Goldwyn-Mayer
# 2          Warner Bros., Jerry Weintraub Productions
# 3       New Line Cinema, 40 Acres & A Mule Filmworks
# 4  Polygram Filmed Entertainment, Working Title F...
#
#                                    writers              directors  \
# 0  Steve Koren, Will Ferrell, Chris Kattan       John Fortenberry
# 1               Oliver Sacks, Steve Levitt          Irwin Winkler
# 2            Sydney Newman, Don MacPherson    Jeremiah S. Chechik
# 3                                Spike Lee              Spike Lee
# 4                    Ethan Coen, Joel Coen  Joel Coen, Ethan Coen
#
#                             casting directors  \
# 0                              Jeff Greenberg
# 1  Kerry Barden, Billy Hopkins, Suzanne Smith
# 2                                Susie Figgis
# 3                                 Aisha Coley
# 4                               John S. Lyons
#
#                                                 cast  \
# 0  Will Ferrell, Chris Kattan, Raquel Gardner, Vi...
# 1  Val Kilmer, Mira Sorvino, Kelly McGillis, Stev...
# 2  Ralph Fiennes, Uma Thurman, Sean Connery, Patr...
# 3  Damon Wayans, Savion Glover, Jada Pinkett Smit...
# 4  Jeff Bridges, John Goodman, Julianne Moore, St...
#
#                        countries  \
# 0                  United States
# 1                  United States
# 2                  United States
# 3                  United States
# 4  United States, United Kingdom
#
#                                         age restrict  \
# 0  Argentina:13, Australia:M, Brazil:14, Canada:P...
# 1  Argentina:13, Australia:M, Canada:PG::(Alberta...
# 2  Argentina:13, Australia:PG, Brazil:10, Canada:...
# 3  Australia:MA, Finland:K-15, France:Tous public...
# 4  Argentina:16, Argentina:18::(cable rating), Au...
#
#                                                 plot  \
# 0  Two dim-witted brothers dream of owning their ...
# 1  A blind man has an operation to regain his sig...
# 2  Two British Agents team up to stop Sir August ...
# 3  A frustrated African-American TV writer propos...
# 4  Jeff "The Dude" Lebowski, mistaken for a milli...
#
#                                         plot outline  \
# 0  The Roxbury Guys, Steve and Doug Butabi, want ...
# 1  First Sight is true to the title from start to...
# 2  British Ministry Agent John Steed, under direc...
# 3  Dark, biting satire of the television industry...
# 4  When "the dude" Lebowski is mistaken for a mil...
#
#                                             keywords  \
# 0  woman-on-top, nightclub, car-accident, 1990s, ...
# 1  visual-agnosia, brother-sister-relationship, r...
# 2  good-versus-evil, heroine, evil-man, villain, ...
# 3  television-industry, african-american, referen...
# 4  rug, nihilism, pornographer, bowling-alley, de...
#
#                                 genres  \
# 0               Comedy, Music, Romance
# 1                       Drama, Romance
# 2  Action, Adventure, Sci-Fi, Thriller
# 3                 Comedy, Drama, Music
# 4                 Comedy, Crime, Sport
#
#                                             taglines  \
# 0                                             Score!
# 1  Only Love Can Bring You To Your Senses., Scien...
# 2  Mrs. Peel, we're needed., Extraordinary crimes...
# 3                   Starring the great negroe actors
# 4  Hay quienes tratan de ganarse la vida sin move...
#
#                                             synopsis
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  In a New York City residence, Pierre Delacroix...
# 4  A tumbleweed rolls up a hillside just outside ...

# %% [markdown]
# Columns relevant to us are:
# - title
# - age restrict
# - year may be of relevance in examining changes in cultural norms over time. E.g. a certain curse word might get a movie an MA rating in the 1960s but not in the 2020s.
# - budget and opening weekend may be of relevance in examining impact of classification on the movie's net.
# - imdbid may be of relevance for joining other data through the imdb database.

# %%
print(screenplays[0][:100])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(screenplays[0][:100])
#
# NameError: name 'screenplays' is not defined

# %% [markdown]
# ## 0.2 Merging Data

# %% [markdown]
# Use filename patterns to distinguish titles from imdbids

# %%
# Extract movie titles and IDs
movie_titles, ids = zip(*[
    (f.split("_", 1)[0], f.split("_", 1)[1].split(".", 1)[0])
    for f in screenplays.keys()])

# Print first 10 titles and IDs
for i, (title, id) in enumerate(zip(movie_titles, ids)):
    if i == 10: 
        break
    print(f"Title: {title}   ID: {id}")
# Out:
# Title: 10 Cloverfield Lane   ID: 1179933
# Title: 10 Things I Hate About You   ID: 0147800
# Title: 101 Days of 101 Dalmatians   ID: 0249328
# Title: 12 Angry Men   ID: 0118528
# Title: 12 Monkeys   ID: 0114746
# Title: 12 Years a Slave   ID: 2024544
# Title: 127 Hours   ID: 1542344
# Title: 13 13 13   ID: 2991516
# Title: 1408   ID: 0450385
# Title: 1492 Conquest of Paradise   ID: 0103594

# %% [markdown]
# Read screenplay text data into a Pandas DataFrame.

# %%
# Create a dataframe from screenplays
screenplays_df = pd.DataFrame({
    'imdbid': [
        os.path.splitext(f.split("_", 1)[1])[0].replace(".txt", "") for f in screenplays.keys()
        ],
    'screenplay': screenplays.values()
})
screenplays_df.head()
# Out:
#     imdbid                                         screenplay
# 0  1179933  The Cellar\n\nby\nJosh Campbell & Matt Stuecke...
# 1  0147800  \n                               TEN THINGS I ...
# 2  0249328  107\n
# #2\n40] _DALMATIANS MARCH 17, 1995\n\nEX...
# 3  0118528  PLEASE COPY AND RETURN |\n\nâââ_âââ...
# 4  0114746  \n\t\t\t\tTWELVE MONKEYS\n\t    \n\t\t        ...

# %% [markdown]
# Display data info for two dataframes.

# %%
print(meta_df.info())
print(screenplays_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2858 entries, 0 to 2857
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   imdbid                     2858 non-null   int64
#  1   title                      2858 non-null   object
#  2   akas                       2652 non-null   object
#  3   year                       2858 non-null   int64
#  4   metascore                  2858 non-null   int64
#  5   imdb user rating           2858 non-null   int64
#  6   number of imdb user votes  2858 non-null   int64
#  7   awards                     2243 non-null   object
#  8   opening weekend            1739 non-null   object
#  9   producers                  2640 non-null   object
#  10  budget                     1624 non-null   object
#  11  script department          2220 non-null   object
#  12  production companies       2682 non-null   object
#  13  writers                    2696 non-null   object
#  14  directors                  2658 non-null   object
#  15  casting directors          2141 non-null   object
#  16  cast                       2806 non-null   object
#  17  countries                  2678 non-null   object
#  18  age restrict               2526 non-null   object
#  19  plot                       2709 non-null   object
#  20  plot outline               2457 non-null   object
#  21  keywords                   2601 non-null   object
#  22  genres                     2846 non-null   object
#  23  taglines                   2256 non-null   object
#  24  synopsis                   1852 non-null   object
# dtypes: int64(5), object(20)
# memory usage: 558.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2858 entries, 0 to 2857
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   imdbid      2858 non-null   object
#  1   screenplay  2858 non-null   object
# dtypes: object(2)
# memory usage: 44.8+ KB
# None

# %% [markdown]
# Merge metadata with screenplay text data.

# %%
# merge with metadata on imdbid
if screenplays_df['imdbid'].dtype != 'int':
    screenplays_df['imdbid'] = screenplays_df['imdbid'].astype(int)
    
df = meta_df.merge(screenplays_df, on='imdbid')
df.head()
# Out:
#    imdbid                   title  \
# 0  120770  A Night at the Roxbury
# 1  132512          At First Sight
# 2  118661            The Avengers
# 3  215545              Bamboozled
# 4  118715        The Big Lebowski
#
#                                                 akas  year  metascore  \
# 0  Une nuit au Roxbury (France), Movida en el Rox...  1998         26
# 1  Sight Unseen (United States), Premier regard (...  1999         40
# 2  Chapeau melon et bottes de cuir (France), Mit ...  1998         12
# 3  The Very Black Show (France), It's Showtime (G...  2000         54
# 4  El gran Lebowski (Spain), O Grande Lebowski (P...  1998         71
#
#    imdb user rating  number of imdb user votes  \
# 0                 6                      56537
# 1                 6                      12922
# 2                 3                      40784
# 3                 6                      10373
# 4                 8                     724388
#
#                                               awards  \
# 0                                                NaN
# 1                                                NaN
# 2  FMCJ Award 1998, Golden Reel Award 1999, Razzi...
# 3  Golden Berlin Bear 2001, Black Reel 2001, Imag...
# 4  Honorable Mention 1998, ACCA 1998, Golden Berl...
#
#                            opening weekend  \
# 0                          United States:
# 1                          United States:
# 2  United States: $10,305,957, 16 Aug 1998
# 3                          United States:
# 4   United States: $5,533,844, 08 Mar 1998
#
#                                            producers                   budget  \
# 0  Marie Cantin, Erin Fraser, Amy Heckerling, Ste...  $17,000,000 (estimated)
# 1           Rob Cowan, Roger Paradiso, Irwin Winkler  $60,000,000 (estimated)
# 2                       Susan Ekins, Jerry Weintraub  $60,000,000 (estimated)
# 3          Jon Kilik, Spike Lee, Kisha Imani Cameron  $10,000,000 (estimated)
# 4  Tim Bevan, John Cameron, Ethan Coen, Eric Fell...  $15,000,000 (estimated)
#
#                       script department  ...              directors  \
# 0                                   NaN  ...       John Fortenberry
# 1                                   NaN  ...          Irwin Winkler
# 2         Sharon Mansfield, Anna Worley  ...    Jeremiah S. Chechik
# 3  Shari L. Carpenter, Carolyn De Sousa  ...              Spike Lee
# 4                         T. Kukovinski  ...  Joel Coen, Ethan Coen
#
#                             casting directors  \
# 0                              Jeff Greenberg
# 1  Kerry Barden, Billy Hopkins, Suzanne Smith
# 2                                Susie Figgis
# 3                                 Aisha Coley
# 4                               John S. Lyons
#
#                                                 cast  \
# 0  Will Ferrell, Chris Kattan, Raquel Gardner, Vi...
# 1  Val Kilmer, Mira Sorvino, Kelly McGillis, Stev...
# 2  Ralph Fiennes, Uma Thurman, Sean Connery, Patr...
# 3  Damon Wayans, Savion Glover, Jada Pinkett Smit...
# 4  Jeff Bridges, John Goodman, Julianne Moore, St...
#
#                        countries  \
# 0                  United States
# 1                  United States
# 2                  United States
# 3                  United States
# 4  United States, United Kingdom
#
#                                         age restrict  \
# 0  Argentina:13, Australia:M, Brazil:14, Canada:P...
# 1  Argentina:13, Australia:M, Canada:PG::(Alberta...
# 2  Argentina:13, Australia:PG, Brazil:10, Canada:...
# 3  Australia:MA, Finland:K-15, France:Tous public...
# 4  Argentina:16, Argentina:18::(cable rating), Au...
#
#                                                 plot  \
# 0  Two dim-witted brothers dream of owning their ...
# 1  A blind man has an operation to regain his sig...
# 2  Two British Agents team up to stop Sir August ...
# 3  A frustrated African-American TV writer propos...
# 4  Jeff "The Dude" Lebowski, mistaken for a milli...
#
#                                         plot outline  \
# 0  The Roxbury Guys, Steve and Doug Butabi, want ...
# 1  First Sight is true to the title from start to...
# 2  British Ministry Agent John Steed, under direc...
# 3  Dark, biting satire of the television industry...
# 4  When "the dude" Lebowski is mistaken for a mil...
#
#                                             keywords  \
# 0  woman-on-top, nightclub, car-accident, 1990s, ...
# 1  visual-agnosia, brother-sister-relationship, r...
# 2  good-versus-evil, heroine, evil-man, villain, ...
# 3  television-industry, african-american, referen...
# 4  rug, nihilism, pornographer, bowling-alley, de...
#
#                                 genres  \
# 0               Comedy, Music, Romance
# 1                       Drama, Romance
# 2  Action, Adventure, Sci-Fi, Thriller
# 3                 Comedy, Drama, Music
# 4                 Comedy, Crime, Sport
#
#                                             taglines  \
# 0                                             Score!
# 1  Only Love Can Bring You To Your Senses., Scien...
# 2  Mrs. Peel, we're needed., Extraordinary crimes...
# 3                   Starring the great negroe actors
# 4  Hay quienes tratan de ganarse la vida sin move...
#
#                                             synopsis  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  In a New York City residence, Pierre Delacroix...
# 4  A tumbleweed rolls up a hillside just outside ...
#
#                                           screenplay
# 0  \n\n\t\t\t    A NIGHT AT THE ROXBURY \n\n\n\t\...
# 1  AT FIRST SIGHT\n\nEXT. VALLEY - DUSK \nGold li...
# 2  \n\n\t\t\t\t\tTHE AVENGERS\n\n\t\t\t\tScreenpl...
# 3  \t\t\t\tBamboozled\n\n\t\t\t\tby\n\n\t\t\t\tSp...
# 4  \n\n\t\t\tTHE BIG LEBOWSKI\n\nWe are floating ...
#
# [5 rows x 26 columns]

# %% [markdown]
# # 1. Exploration and Simple Preprocessing

# %%
df.columns
# Out:
# Index(['imdbid', 'title', 'akas', 'year', 'metascore', 'imdb user rating',
#        'number of imdb user votes', 'awards', 'opening weekend', 'producers',
#        'budget', 'script department', 'production companies', 'writers',
#        'directors', 'casting directors', 'cast', 'countries', 'age restrict',
#        'plot', 'plot outline', 'keywords', 'genres', 'taglines', 'synopsis',
#        'screenplay'],
#       dtype='object')

# %% [markdown]
# ## 1.1 Countries

# %%
df['countries'].value_counts()
# Out:
# countries
# United States                                                          1613
# United Kingdom                                                           96
# United Kingdom, United States                                            92
# United States, United Kingdom                                            87
# United States, Canada                                                    58
#                                                                        ...
# United States, Germany, Italy, Spain, France, Japan, United Kingdom       1
# Finland, Estonia, Germany, United Kingdom                                 1
# United States, Canada, New Zealand                                        1
# Canada, Germany                                                           1
# United Kingdom, China, United States                                      1
# Name: count, Length: 360, dtype: int64

# %% [markdown]
# Checking here whether we're dealing exclusively with screenplays written in English or not.

# %%
# find samples of screenplays in which countries !contain "United States", "United Kingdom", "Canada" 
non_anglo = df[df['countries'].str.contains("United States|United Kingdom|Canada|Australia") == False]
non_anglo
# Out:
#        imdbid                title  \
# 42    5639354    A Fantastic Woman
# 49    6896536              Foxtrot
# 50    5304464            Happy End
# 52    6304162             Loveless
# 57    3741632   The Leisure Seeker
# ...       ...                  ...
# 2540  6543896        Al Wazeer Jay
# 2541  6484982               Newton
# 2552  2150716    The Lobster's Cry
# 2745    93593  On the Silver Globe
# 2748  1706620          Snowpiercer
#
#                                                    akas  year  metascore  \
# 42    Eine fantastische Frau (Germany), A Fantastic ...  2017         86
# 49    運命は踊る (Japan, Japanese title), 今天跳舞不打仗 (Taiwan...  2017         88
# 50    Un final feliz (Mexico), ハッピーエンド (Japan, Japan...  2017         72
# 52    Нелюбовь (Russia), Faute d'amour (France), Lov...  2017         86
# 57    Ella & John - The Leisure Seeker (Italy), L'éc...  2017         45
# ...                                                 ...   ...        ...
# 2540                              Al Wazeer Jay (Egypt)  1986         -1
# 2541                  Νιούτον (Greece), Ньютон (Russia)  2017         -1
# 2552  The Lobster's Cry (World-wide, English title),...  2012         -1
# 2745  On the Silver Globe (United States), On the Si...  1988         72
# 2748  Transperceneige (South Korea), Seolgungnyeolch...  2013         84
#
#       imdb user rating  number of imdb user votes  \
# 42                   7                      22299
# 49                   7                       6533
# 50                   6                      12970
# 52                   7                      29211
# 57                   6                       7285
# ...                ...                        ...
# 2540                 6                         10
# 2541                 7                      16310
# 2552                 7                         54
# 2745                 7                       2396
# 2748                 7                     313718
#
#                                                  awards  \
# 42    Oscar 2018, Golden Globe 2018, Golden Boll in ...
# 49    Asia Pacific Screen Award 2017, City of Athens...
# 50    Palme d'Or 2017, European Film Award 2017, Mag...
# 52    Oscar 2018, Golden Globe 2018, BAFTA Film Awar...
# 57    Golden Globe 2018, Capri Ensemble Cast Award 2...
# ...                                                 ...
# 2540                                                NaN
# 2541  Asia Pacific Screen Award 2017, Asian Film Awa...
# 2552  Grand Prix 2012, CinEuphoria 2014, César 2013,...
# 2745              International Fantasy Film Award 1989
# 2748  Movies for Grownups Award 2015, Saturn Award 2...
#
#                             opening weekend  \
# 42                                      NaN
# 49                                      NaN
# 50                                      NaN
# 52                                      NaN
# 57                                  Italy:
# ...                                     ...
# 2540                                    NaN
# 2541                                    NaN
# 2552                                    NaN
# 2745                                    NaN
# 2748  South Korea: $14,842,419, 01 Aug 2013
#
#                                               producers  \
# 42    Maren Ade, Alexander Bohr, Eduardo Castro, Mar...
# 49    Marc Baschet, Martina Valentina Baumgartner, D...
# 50    Stefan Arndt, Christopher Granier-Deferre, Mic...
# 52    Pascal Caucheteux, Gleb Fetisov, Sergey Melkum...
# 57    Cobi Benatoff, Elisabetta Boni, Ferdinando Bon...
# ...                                                 ...
# 2540                                                NaN
# 2541  Shiladitya Bora, Raghav Gupta, Kanupriya, Suni...
# 2552  Nicolas Guiot, Sophie Leclercq, Fabrice Préel-...
# 2745                                                NaN
# 2748  Seung-yun Ahn, Jisun Back, Robert Bernacchi, D...
#
#                        budget  \
# 42                        NaN
# 49                        NaN
# 50                        NaN
# 52                        NaN
# 57                        NaN
# ...                       ...
# 2540                      NaN
# 2541                      NaN
# 2552                      NaN
# 2745                      NaN
# 2748  $39,200,000 (estimated)
#
#                                       script department  ...  \
# 42    Eliseo Altunaga, Guillermo Calderón, Antonia O...  ...
# 49                                                  NaN  ...
# 50                                       Maggie Perlado  ...
# 52                                Konstantin Tishchenko  ...
# 57                         Ben Barker, Katherine Steets  ...
# ...                                                 ...  ...
# 2540                                                NaN  ...
# 2541                                        Varun Kumar  ...
# 2552                                     Amandine Lemal  ...
# 2745                                                NaN  ...
# 2748            Hyun Kim Kyu, Darcy Paquet, Bo Eun Park  ...
#
#                   directors                        casting directors  \
# 42          Sebastián Lelio            Alejandra Alaff, Moira Miller
# 49              Samuel Maoz              Tanja Schuh, Chamutal Zerem
# 50           Michael Haneke  David El Hakim, Kris Portier de Bellair
# 52       Andrey Zvyagintsev                                      NaN
# 57              Paolo Virzì              Tara Feldstein, Chase Paris
# ...                     ...                                      ...
# 2540  Ibrahim Al Shaqanqiry                                      NaN
# 2541          Amit Masurkar         Romil Modi, Tejas Girish Thakker
# 2552          Nicolas Guiot                      Valérie Trajanovski
# 2745       Andrzej Zulawski                                      NaN
# 2748           Bong Joon Ho                   Jenny Jue, Johanna Ray
#
#                                                    cast  \
# 42    Daniela Vega, Francisco Reyes, Luis Gnecco, Al...
# 49    Lior Ashkenazi, Sarah Adler, Yonaton Shiray, S...
# 50    Isabelle Huppert, Jean-Louis Trintignant, Math...
# 52    Maryana Spivak, Aleksey Rozin, Matvey Novikov,...
# 57    Helen Mirren, Donald Sutherland, Christian McK...
# ...                                                 ...
# 2540  Osama Abbas, Umran Bahar, Ahmad Bedair, Mohame...
# 2541  Rajkummar Rao, Pankaj Tripathi, Anjali Patil, ...
# 2552  Jana Bittnerová, Tatiana Gontcharova, Anton Ko...
# 2745  Andrzej Seweryn, Jerzy Trela, Grazyna Dylag, W...
# 2748  Chris Evans, Song Kang-Ho, Ed Harris, John Hur...
#
#                                  countries  \
# 42                   Chile, Spain, Germany
# 49    Israel, Switzerland, Germany, France
# 50                France, Austria, Germany
# 52        Russia, France, Germany, Belgium
# 57                           Italy, France
# ...                                    ...
# 2540                                 Egypt
# 2541                                 India
# 2552                       France, Belgium
# 2745                                Poland
# 2748           South Korea, Czech Republic
#
#                                            age restrict  \
# 42    Australia:M, Brazil:14, Canada:14A::(Alberta),...
# 49    Australia:MA15+, Canada:14A::(Alberta), Canada...
# 50    Australia:M, Austria:16, Brazil:14, Canada:14A...
# 52    Argentina:16, Australia:MA15+, Brazil:14, Cana...
# 57    Australia:M, Austria:10, Brazil:14, Canada:PG:...
# ...                                                 ...
# 2540                                                NaN
# 2541  Argentina:13, Australia:MA15+, Germany:Not Rat...
# 2552                                                NaN
# 2745                              United States:Unrated
# 2748  Argentina:16, Australia:MA15+, Brazil:16, Cana...
#
#                                                    plot  \
# 42    Marina, a transgender woman who works as a wai...
# 49    A troubled family must face the facts when som...
# 50    A well-to-do French family deals with a series...
# 52    A couple going through a divorce must team up ...
# 57    A runaway couple go on an unforgettable journe...
# ...                                                 ...
# 2540                                                NaN
# 2541  A government clerk on election duty in the con...
# 2552  A Russian soldier returns from war service in ...
# 2745  A team of astronauts land on an inhabitable pl...
# 2748  In a future where a failed climate-change expe...
#
#                                            plot outline  \
# 42    Somewhere in Santiago at a dimly-lit nightclub...
# 49    Michael and Dafna are devastated when Army off...
# 50    Gradually succumbing to dementia, George Laure...
# 52    Still living under the same roof, the Moscow c...
# 57    A runaway couple go on an unforgettable journe...
# ...                                                 ...
# 2540                                                NaN
# 2541  As India, the world's largest democracy, brace...
# 2552                                                NaN
# 2745  A small group of cosmic explorers, including a...
# 2748  Set in 2031, the entire world is frozen except...
#
#                                                keywords  \
# 42    transgender-woman, female-nudity, death-of-lov...
# 49    foreign-occupation, jarhead, bare-breasts, fem...
# 50    self-hatred, 12-year-old, hairdresser, depress...
# 52    missing-child, broken-family, divorce, written...
# 57    recreational-vehicle, road-trip, husband-wife-...
# ...                                                 ...
# 2540                                                NaN
# 2541  election, officer, honesty, duty, forest, trib...
# 2552  chechnya, soldier, return-from-war, russian-fa...
# 2745  colonization, mythology, voice-over-narration,...
# 2748  train, perpetual-winter, closed-ecological-sys...
#
#                                  genres  \
# 42                                Drama
# 49                                Drama
# 50                                Drama
# 52                                Drama
# 57    Adventure, Comedy, Drama, Romance
# ...                                 ...
# 2540                             Comedy
# 2541                      Comedy, Drama
# 2552          Short, Drama, Family, War
# 2745  Adventure, Drama, Fantasy, Sci-Fi
# 2748              Action, Drama, Sci-Fi
#
#                                                taglines  \
# 42                       Fearless, Powerful, Ravishing.
# 49                                                  NaN
# 50    Don't believe the title of this Michael Haneke...
# 52    A Missing Child. A Marriage Destroyed. A Count...
# 57    A Once in a Lifetime Roadtrip They Will Never ...
# ...                                                 ...
# 2540                                                NaN
# 2541                    Electoral Rumble in the jungle.
# 2552                                                NaN
# 2745                                                NaN
# 2748  AD 2031: the passengers in the train are the o...
#
#                                                synopsis  \
# 42                                                  NaN
# 49                                                  NaN
# 50                                                  NaN
# 52    Whether or not it is designed as an allegory o...
# 57    John and Ella Robina have shared a wonderful l...
# ...                                                 ...
# 2540                                                NaN
# 2541  Nutan (Newton) Kumar, a rookie government cler...
# 2552                                                NaN
# 2745                                                NaN
# 2748  In 2014, an attempt to counteract global warmi...
#
#                                              screenplay
# 42    A Fantastic Woman\n\nScreenplay by\nSebastian ...
# 49    FOXTROT\n\nA screenplay by Samuel Maoz\n
# 1. IN...
# 50    âHAPPY ENDâ\n\nMichael Haneke\n
# HAPPY END ...
# 52    LOVELESS\n\nOleg Negin, Andrey Zvyagintsev\n
# L...
# 57    THE LEISURE SEEKER\n\nWritten by\n\nStephen Am...
# ...                                                 ...
# 2540  FOX STAR STUDIOS\n\nPresents\n\nNEERJA\n\nA Bl...
# 2541  EXT. SMALL TOWN STREET- DAY 1\nA red, dusty ro...
# 2552  THE LOBSTER\n\nWritten by\n\nYorgos Lanthimos ...
# 2745  SLIVER\n\nby Ira Levin\n\nScreenplay by Joe Es...
# 2748  SNOWPIERCER\n\nby\nBONG Joon-ho\n\nRevised by\...
#
# [130 rows x 26 columns]

# %%
non_anglo['screenplay'].sample(20)
# Out:
# 2180    NEVER LOOK AWAY\n\nAn original screenplay\nby\...
# 627     \n\n\n\n\n\n                                JE...
# 1462    \nLa Belle et la BÃªte (Beauty and the Beast) ...
# 1385    aC EDS\n\n \n
# ROMA\n\n \n\nWritten and Directe...
# 515     \n                                  "THE GRAPE...
# 671     \n\n\n\n\n\n                             LES T...
# 2060    sbs\n\nPRODUCTIONS\n\nFRANKIE\n\nby\n\nMaurici...
# 838     Movie: MewTwo Strikes Back ***This is not an o...
# 920     The Seventh Seal\n \nThe night had brought lit...
# 2128    LAND OF MIN\n\n \n\nGI\n\nWritten by\n\nMartin...
# 1217    RAN\n\nScreenplay by\nAkira Kurosawa &\nHideo ...
# 1537    DUPLEX\nby\n\nLARRY DOYLE\n\nRevisions by\nGre...
# 1386    Southern Belle\n\nBy\n\nRhonnie Fordham\n\n229...
# 815     \n\n\n\n\n\n\n\n\n\n                     THE P...
# 811     \n\n\n\n\n\n\n\n\n\n                          ...
# 1685    MOEBIUS\n\nScreenplay by\nNeil Cohen\n\nBased ...
# 2193    PAIN AND GLORY\n\nOriginal script by\nPedro Al...
# 665     \n\n\n\n\n\n                              LE D...
# 1426    8mm\n\n\n"8MM", by Andrew Kevin Walker \n\n\n\...
# 772     \n\n\n\n\n\n                           MUTE WI...
# Name: screenplay, dtype: object

# %% [markdown]
# E.g. La Belle et La Bete

# %%
non_anglo.loc[1462,'screenplay']
# Out:
# '\nLa Belle et la BÃªte (Beauty and the Beast) \n\nLa Belle et la BÃªte (Beauty and the Beast)\nOPENING TITLE:\n\nChildren believe what we tell them. \nThey have complete faith in us. \nThey believe that a rose plucked \nfrom a garden can bring drama to \na family. They believe that the \nhands of a human beast will smoke \nwhen he kills a victim, and that \nthis beast will be shamed when \nconfronted by a young girl. They \nbelieve in a thousand other simple \nthings. I ask of you a little of \nthis childlike simplicity, and to \nbring us luck let me speak four \ntruly magic words, childhood\'s \nOpen Sesame: \n\n\n\n\t\t\t"Once upon a time..." \n\n\n\nBeauty lives in the country with her father, a 17th-century merchant who has \nlost all his money; her brother, Ludovic, whose only interests are drinking \nand gambling; and her two sisters, Felicie and Adelaide, who are motivated \nentirely by spite, selfishness and vanity. Her brother\'s constant companion, \nAvenant, is a frequent visitor to the house.\n \nLudovic and Avenant are shooting arrows at a target fixed onto the wall of \nthe house.\n\nFelicie and Adelaide are inside. \n\n\t\t\t\tFELICIE \n\t\t\t(angrily) \n\t\tOh, that wretched girl! \n\n\t\t\t\tADELAIDE \n\t\tYou know she can\'t do anything right. \n\n\t\t\t\tLUDOVIC \n\t\t\t(taking aim and shooting)\n\t\tA bad one. \n\nHe steps aside. Avenant aims. \n\n\t\t\t\tLUDOVIC\n\t\tYour foot.\n \n\t\t\t\tAVENANT \n\t\tWhat about my foot?\n \n\t\t\t\tLUDOVIC\n\t\tYou\'re cheating, it\'s not on the mark.\n \nAvenant shoots. The arrow flies straight through the upper window of the \nhouse and impales itself in the floor next to a silk cushion. A little dog \nleaps up from the cushion, barking furiously. Beauty is attending to her \nsisters who, in sharp, contrast to her simple attire, are dressed in rich \nsilks and feathers. \n\n\t\t\t\tFELICIE \n\t\tWhat\'s going on? \n\n\t\t\t\tADELAIDE \n\t\tThey\'ve just shot an arrow into the room!\n \n \t\t\t\tFELICIE\n\t\tOh!\n \n\t\t\t\tADELAIDE \n\t\t\t(going to the window and shouting)\n\t\tYou hooligans! You could have hit one of us in \n\t\tthe eye!\n \nLudovic and Avenant rush up to the house. \n\n\t\t\t\tAVENANT\n\t\tIs Beauty all right?\n \n\t\t\t\tADELAIDE \n\t\t\t(shouting out of the window) \n\t\tBeauty! Always Beauty! Who cares about Beauty? \n\t\tYou nearly killed Cabriole! \n\nLudovic and Avenant go into the house and wait at the foot of the stairs.\n\n\t\t\t\tLUDOVIC \n\t\t\t(ironically)\n\t\tHere they come. \n\nFelicie and Adelaide hurry down.\n\n\t\t\t\tFELICIE \n\t\t\t(shouting)\n\t\tBeauty, you can wash the floor. We\'ll be late \n\t\tfor the duchess.\n\n\t\t\t\tADELAIDE \n\t\t\t(to the two men) \n\t\tMurderers! \n\n\t\t\t\tLUDOVIC \n\t\t\t(to Avenant) \n\t\tMy sisters are such bitches.\n \n\t\t\t\tFELICIE \n\t\t\t(to Adelaide)\n\t\tDrinking, chasing women and cheating at cards, \n\t\tthat\'s all they ever think about. They couldn\'t \n\t\tgive a damn about anything else.\n\n\t\t\t\tLUDOVIC \n\t\t\t(to Avenant) \n\t\tWhen one is poor, one stays at home to do the \n\t\tlaundry and polish the pots and pans. Just look \n\t\tat these two sluts -- they think they\'re \n\t\tprincesses. They don\'t even realize that \n\t\tthey\'re the laughing stock of society.\n \n\t\t\t\tADELAIDE \n\t\t\t(to Felicie)\n\t\tSay something! \n\n\t\t\t\tFELICIE \n\t\tHe\'d be only too pleased. \n\nThey flounce out of the house.\n \n\t\t\t\tLUDOVIC\n\t\tOh, such beauties! So ravishing!\n \n \t\t\t\tADELAIDE \n\t\t\t(to Felicie)\n\t\tCome on, we\'ll be late for the concert.\n \n\t\t\t\tLUDOVIC\n \t\t\t(following them out of the house) \n\t\tEnchantresses! Goddesses! Shining lights!\n \n \t\t\t\tFELICIE \n\t\t\t(shouting)\n\t\tHey there! Boys! Boys! \n\n\t\t\t\tLUDOVIC\n \t\t\t(imitating her)\n\t\tBoys! Boys!\n \nFelicie and Adelaide walk across the yard toward a servant who is dozing in a \nsedan chair. \n\n\t\t\t\tADELAIDE \n\t\tOh!\n \nThe boy leaps out of the chair. Felicie sits down. \n\ ...

# %% [markdown]
# Although the tile is in French, the screenplay itself is written in English.

# %% [markdown]
# ## 1.2 Column Selection

# %%
# create a lean version of the dataframe containing only columns clearly relevant to predicting age restrict classification
relevant_cols = ['imdbid', 'title', 'year', 'opening weekend', 'budget', 'age restrict', 'genres', 'screenplay']
df_lean = df[relevant_cols]
df_lean.head()
# Out:
#    imdbid                   title  year  \
# 0  120770  A Night at the Roxbury  1998
# 1  132512          At First Sight  1999
# 2  118661            The Avengers  1998
# 3  215545              Bamboozled  2000
# 4  118715        The Big Lebowski  1998
#
#                            opening weekend                   budget  \
# 0                          United States:   $17,000,000 (estimated)
# 1                          United States:   $60,000,000 (estimated)
# 2  United States: $10,305,957, 16 Aug 1998  $60,000,000 (estimated)
# 3                          United States:   $10,000,000 (estimated)
# 4   United States: $5,533,844, 08 Mar 1998  $15,000,000 (estimated)
#
#                                         age restrict  \
# 0  Argentina:13, Australia:M, Brazil:14, Canada:P...
# 1  Argentina:13, Australia:M, Canada:PG::(Alberta...
# 2  Argentina:13, Australia:PG, Brazil:10, Canada:...
# 3  Australia:MA, Finland:K-15, France:Tous public...
# 4  Argentina:16, Argentina:18::(cable rating), Au...
#
#                                 genres  \
# 0               Comedy, Music, Romance
# 1                       Drama, Romance
# 2  Action, Adventure, Sci-Fi, Thriller
# 3                 Comedy, Drama, Music
# 4                 Comedy, Crime, Sport
#
#                                           screenplay
# 0  \n\n\t\t\t    A NIGHT AT THE ROXBURY \n\n\n\t\...
# 1  AT FIRST SIGHT\n\nEXT. VALLEY - DUSK \nGold li...
# 2  \n\n\t\t\t\t\tTHE AVENGERS\n\n\t\t\t\tScreenpl...
# 3  \t\t\t\tBamboozled\n\n\t\t\t\tby\n\n\t\t\t\tSp...
# 4  \n\n\t\t\tTHE BIG LEBOWSKI\n\nWe are floating ...

# %%
df_lean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2853 entries, 0 to 2852
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   imdbid           2853 non-null   int64
#  1   title            2853 non-null   object
#  2   year             2853 non-null   int64
#  3   opening weekend  1736 non-null   object
#  4   budget           1623 non-null   object
#  5   age restrict     2524 non-null   object
#  6   genres           2841 non-null   object
#  7   screenplay       2853 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 178.4+ KB

# %% [markdown]
# ## 1.3 'age restrict' (target variable)

# %%
df_lean['age restrict'][:50]
# Out:
# 0     Argentina:13, Australia:M, Brazil:14, Canada:P...
# 1     Argentina:13, Australia:M, Canada:PG::(Alberta...
# 2     Argentina:13, Australia:PG, Brazil:10, Canada:...
# 3     Australia:MA, Finland:K-15, France:Tous public...
# 4     Argentina:16, Argentina:18::(cable rating), Au...
# 5     Argentina:13, Australia:MA, Canada:14A::(Manit...
# 6     Argentina:16, Australia:MA, Belgium:KT/EA, Bra...
# 7     Argentina:18, Australia:M, Brazil:14, Canada:P...
# 8     Argentina:13, Australia:M, Canada:14A::(Albert...
# 9     Argentina:Atp, Australia:M, Finland:K-8, Germa...
# 10    Argentina:16, Australia:M, Australia:MA15+, Br...
# 11    Argentina:13, Australia:M, Brazil:10, France:T...
# 12    Argentina:Atp, Australia:G, Australia:PG::(TV ...
# 13    Argentina:16, Argentina:18, Australia:R, Brazi...
# 14    Argentina:Atp, Australia:G, Brazil:Livre, Cana...
# 15    Argentina:Atp, Australia:G, Brazil:Livre::(vid...
# 16                                                  NaN
# 17    Argentina:13, Australia:M, Brazil:12, Finland:...
# 18    Argentina:13, Argentina:16, Australia:PG, Aust...
# 19    Argentina:13, Australia:M, Brazil:12, Canada:P...
# 20    Argentina:Atp, Australia:M, Brazil:14, Canada:...
# 21    Argentina:13, Australia:M, Brazil:14::(video r...
# 22    Argentina:13, Australia:MA, Canada:18A, Canada...
# 23    Argentina:Atp, Australia:PG, Australia:M::(Spe...
# 24    Argentina:16, Australia:M, Brazil:14, Finland:...
# 25    Argentina:13, Australia:M, Canada:PA::(Ontario...
# 26    Argentina:Atp, Australia:PG, Australia:G::(TV ...
# 27    Argentina:13, Australia:M, Brazil:14, Canada:A...
# 28    Argentina:13, Australia:M, Canada:PG, Finland:...
# 29    Argentina:Atp, Australia:PG, Brazil:Livre, Can...
# 30    Australia:M, Canada:PG::(Canadian Home Video r...
# 31    Canada:14A::(Alberta), Canada:PG::(Ontario), C...
# 32    Australia:A, Australia:PG, Brazil:18, Canada:P...
# 33    Argentina:13, Australia:M, Brazil:14, Canada:1...
# 34    Argentina:18, Argentina:16, Australia:R, Austr...
# 35    Argentina:18, Argentina:13, Australia:M, Brazi...
# 36    Argentina:16, Australia:MA, Brazil:18, Canada:...
# 37    Argentina:13, Australia:M, Brazil:12, Canada:1...
# 38    Argentina:13, Australia:M, Brazil:12, Canada:1...
# 39    Argentina:16, Australia:MA15+, Brazil:14, Cana...
# 40    Canada:PG::(British Columbia), Denmark:A::(DVD...
# 41    Argentina:13, Australia:M, Austria:10, Brazil:...
# 42    Australia:M, Brazil:14, Canada:14A::(Alberta),...
# 43    Argentina:13, Australia:MA15+, Austria:12, Bel...
# 44    Argentina:13, Australia:M, Brazil:12, Canada:P...
# 45    Australia:M, Canada:PG::(Alberta), Canada:PG::...
# 46    Argentina:13, Australia:MA15+, Australia:M, Au...
# 47    Australia:M, Brazil:12, Brazil:10::(some episo...
# 48    Argentina:13::(with warning), Australia:M, Bra...
# 49    Australia:MA15+, Canada:14A::(Alberta), Canada...
# Name: age restrict, dtype: object

# %%
# assess missing values in age restrict 
print("Nulls in 'age restrict' column:", df_lean['age restrict'].isnull().sum())
# Out:
# Nulls in 'age restrict' column: 329

# %%
# drop rows with missing values for age restrict 
df_clean = df_lean.dropna(how='any', subset='age restrict')
print("Shape of df_clean:", df_clean.shape)
print("Nulls remaining in 'age restrict':", df_clean['age restrict'].isnull().sum())
# Out:
# Shape of df_clean: (2524, 8)
# Nulls remaining in 'age restrict': 0

# %% [markdown]
# ### 1.3.1 Extracting Australian Classification where available

# %%
# regex pattern for finding Australian classification
pattern = re.compile(r"Australia:([A-Z0-9]+)")

# filter out the Australian age restrict classification 
def find_aus_classification(string):
    if isinstance(string, str):
        match = re.search(pattern, string)
        return match.group(1) if match else pd.NA
    return pd.NA

aus_classifications = df_clean['age restrict'].apply(find_aus_classification)
aus_classifications
# Out:
# 0          M
# 1          M
# 2         PG
# 3         MA
# 4         MA
#         ...
# 2848    MA15
# 2849      PG
# 2850    MA15
# 2851      PG
# 2852    MA15
# Name: age restrict, Length: 2524, dtype: object

# %%
# check value counts for aus_classifications
print(aus_classifications.value_counts())
# Out:
# age restrict
# M       1000
# MA15     411
# PG       355
# MA       194
# R        128
# G        111
# R18       38
# A         36
# SOA       18
# NRC       10
# RC         1
# Name: count, dtype: int64

# %% [markdown]
# From Wiki:
#
# <h3>Early film classification</h3>
#
# "The Commonwealth Film Censorship Board was created in 1917 to view, classify, and censor films imported from overseas. In the early years of the system there were 3 ratings:[4]
#
# G for "general audiences"
# A for "not suitable for children"
# SOA for "suitable for adults only"
# All ratings were advisory in nature and while distributors were required to display them on advertising, there were no restrictions on children's attendance. As such, films with adult ratings were still routinely censored."
#  https://en.wikipedia.org/wiki/Australian_Classification_Board
#
#
# <i>
# <ul> A almost certainly corresponds to G. </ul>
# <ul> NRC is effectively PG. </ul>
# <ul> SOA is more ambiguous, we'll drop this. </ul>
# <ul> Extreme imbalance for 'RC': only one sample means it can't be represented in both training and testing data, so can't be used.  </ul>
# </i>

# %% [markdown]
# Assign aus_classifications back to a new DataFrame as a new column.

# %%
# create a dataset with aus classifications
df_clean.loc[:, 'age restrict aus'] = aus_classifications
df_clean['age restrict aus']
# Out:
# 0                      M
# 1                      M
# 2                     PG
# 3                     MA
# 4                     MA
#                     ...
# 2849                  PG
# 2850                MA15
# 2851                  PG
# 2852                MA15
# age restrict aus     NaN
# Name: age restrict aus, Length: 2525, dtype: object

# %% [markdown]
# Creating a separate dataframe df_aus which will only contain rows with an  interpretable Australian classification.

# %%
df_aus = df_clean.dropna(how='any', subset='age restrict aus')
df_aus.shape
# Out:
# (2302, 9)

# %%
# Now drop rows where 'age restrict aus' is SOA or RC
df_aus = df_aus[~df_aus['age restrict aus'].isin(['SOA', 'RC'])]
df_aus['age restrict aus'].value_counts()
# Out:
# age restrict aus
# M       999
# MA15    411
# PG      355
# MA      194
# R       128
# G       111
# R18      38
# A        36
# NRC      10
# Name: count, dtype: int64

# %%
# ## save as CSVs
# df_clean.to_csv('df_clean.csv')
# df_aus.to_csv('df_aus.csv')

# %% [markdown]
# # Text Preprocessing

# %% [markdown]
# ## Cleaning

# %% [markdown]
# Note:
# - this was our first, simple attempt at text cleaning.
# - A superior attempt can be found in deployed_approach.ipynb.
# - The most comprehensive attempt can be found in final_preprocessing.ipynb, but this approach was not able to be deployed due to time constraints.

# %%
def clean_text(text):
    text = text.lower()  # convert to lower case
    text = re.sub(r'[^\w]', ' ', text)  # remove anything that is not a word char
    text = re.sub(r'[ ]{2,}', ' ', text) # remove extra spaces 
    text = re.sub(r'[ \t]+$', '', text) # remove trailing whitespace
    return text

# %%
df_clean.loc[:,'cleaned_screenplays'] = df_clean['screenplay'].apply(clean_text)
df_clean['cleaned_screenplays']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df_clean.loc[:,'cleaned_screenplays'] = df_clean['screenplay'].apply(clean_text)
#       2 df_clean['cleaned_screenplays']
#
# File c:\Users\bened\anaconda3\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\bened\anaconda3\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\bened\anaconda3\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\bened\anaconda3\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\bened\anaconda3\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[38], line 2, in clean_text(text)
#       1 def clean_text(text):
# ----> 2     text = text.lower()  # convert to lower case
#       3     text = re.sub(r'[^\w]', ' ', text)  # remove anything that is not a word char
#       4     text = re.sub(r'[ ]{2,}', ' ', text) # remove extra spaces
#
# AttributeError: 'float' object has no attribute 'lower'

# %% [markdown]
# ## Stopword Removal

# %%
import nltk 
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\bened\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop_words = stopwords.words("english")

def remove_stopwords(text):
    processed_tokens = []
    for t in text.split():
        if t not in stop_words:
            processed_tokens.append(t)
    return " ".join(processed_tokens)

# %%
df_clean.loc[:,'cleaned_screenplays'] = df_clean['cleaned_screenplays'].apply(remove_stopwords)
df_clean['cleaned_screenplays'].head()
# Out:
# 0    night roxbury written steve koren ferrell chri...
# 1    first sight ext valley dusk gold light dapplin...
# 2    avengers screenplay macpherson june 21 1995 1b...
# 3    bamboozled spike lee black screen hear voice m...
# 4    big lebowski floating steep scrubby slope hear...
# Name: cleaned_screenplays, dtype: object

# %% [markdown]
# ## Stemming

# %%
from nltk.stem import SnowballStemmer

# %%
def stem(text):
    stemmed_tokens = []
    stemmer = SnowballStemmer("english")
    for t in text.split():
        t = stemmer.stem(t)
        stemmed_tokens.append(t)
    return " ".join(stemmed_tokens)

# %%
df_clean.columns
# Out:
# Index(['imdbid', 'title', 'year', 'opening weekend', 'budget', 'age restrict',
#        'genres', 'screenplay', 'age restrict aus', 'cleaned_screenplays'],
#       dtype='object')

# %%
df_clean.loc[:,'cleaned_screenplays'] = df_clean['cleaned_screenplays'].apply(stem)
df_clean['cleaned_screenplays']
# Out:
# 0       night roxburi written steve koren ferrel chris...
# 1       first sight ext valley dusk gold light dappl a...
# 2       aveng screenplay macpherson june 21 1995 1blue...
# 3       bamboozl spike lee black screen hear voic malc...
# 4       big lebowski float steep scrubbi slope hear ma...
#                               ...
# 2848    war world screenplay josh friedman david koepp...
# 2849    june 29 1994 sleep dan sullivan fred lebow ext...
# 2850    wind river written taylor sheridan open snow c...
# 2851    wrong accus pat proft proft thing intern revis...
# 2852    never realli screenplay lynn ramsay base novel...
# Name: cleaned_screenplays, Length: 2524, dtype: object

# %%
df_clean['age restrict aus'].value_counts()
# Out:
# age restrict aus
# M        877
# PG       335
# MA15+    314
# MA       173
# R        103
# G         89
# Name: count, dtype: int64

# %% [markdown]
# If we narrow scope to Aus classifications for now, we have 6 target classes

# %% [markdown]
# # Feature and Target Engineering

# %% [markdown]
# Encode Target (Aus ratings)

# %%
aus_target_map = {
    'G': 0,
    'PG': 1,
    'M': 2,
    'MA': 3,
    'MA15+': 4,
    'R': 5
} 

y = df_aus['age restrict aus'].map(aus_target_map) 
y.value_counts()
# Out:
# age restrict aus
# 2    877
# 1    335
# 4    314
# 3    173
# 5    103
# 0     89
# Name: count, dtype: int64

# %%
def compute_class_balance(y): 
    classes = sorted(list(y.unique()))
    value_counts = y.value_counts()
    for c in classes: 
        class_ratio = value_counts[c] / len(y) * 100
        print(f"{c} represents {class_ratio}% of target data")

# %%
compute_class_balance(y)
# Out:
# 0 represents 4.706504494976203% of target data
# 1 represents 17.715494447382337% of target data
# 2 represents 46.37757800105764% of target data
# 3 represents 9.148598625066102% of target data
# 4 represents 16.604970914859862% of target data
# 5 represents 5.4468535166578524% of target data

# %% [markdown]
# There is a significant class imbalance with regard to movies rated M (3); the other imbalances are less significant.

# %%
X = df_aus['screenplay'].apply(clean_text)
X = X.apply(remove_stopwords)
X = X.apply(stem)
X
# Out:
# 0       night roxburi written steve koren ferrel chris...
# 1       first sight ext valley dusk gold light dappl a...
# 2       aveng screenplay macpherson june 21 1995 1blue...
# 4       big lebowski float steep scrubbi slope hear ma...
# 5       boy side scene 1 jane thank jane deluca johnni...
#                               ...
# 2847    vo ud twenti pirst centuri por trale wreeten b...
# 2849    june 29 1994 sleep dan sullivan fred lebow ext...
# 2850    wind river written taylor sheridan open snow c...
# 2851    wrong accus pat proft proft thing intern revis...
# 2852    never realli screenplay lynn ramsay base novel...
# Name: screenplay, Length: 1891, dtype: object

# %% [markdown]
# # Data Split

# %% [markdown]
# ## Splitting by 'year'

# %%
df_aus['year'].describe()
# Out:
# count    1891.000000
# mean     1997.916446
# std        16.889852
# min      1922.000000
# 25%      1991.000000
# 50%      2001.000000
# 75%      2010.000000
# max      2021.000000
# Name: year, dtype: float64

# %% [markdown]
# The most recent 25% of the data comes from 2010 onwards.  We will take this as test data in the hopes our model will still work in classifying the most recent films.

# %%
test_index = df_aus.loc[df_aus['year'] > 2010].index
test_index
# Out:
# Index([  39,   43,   44,   46,   48,   51,   52,   55,  101,  110,
#        ...
#        2829, 2830, 2832, 2837, 2839, 2844, 2845, 2847, 2850, 2852],
#       dtype='int64', length=420)

# %%
test_ratio = len(test_index) / len(df_aus.index)
print(f"Films released after 2010 (data reserved for testing) represent {test_ratio} of the dataset")
# Out:
# Films released after 2010 (data reserved for testing) represent 0.222104706504495 of the dataset

# %%
from sklearn.model_selection import train_test_split 

X_test = X.loc[test_index]
y_test = y.loc[test_index]

X_data = X.loc[~X.index.isin(test_index)]
y_data = y.loc[~y.index.isin(test_index)]

# randomized split for train-val 
X_train, X_val, y_train, y_val = train_test_split(X_data, y_data, test_size=0.2, random_state=1)

compute_class_balance(y_train)
compute_class_balance(y_val)
compute_class_balance(y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[141], line 12
#       9 # randomized split for train-val
#      10 X_train, X_val, y_train, y_val = train_test_split(X_data, y_data, test_size=0.2, random_state=1)
# ---> 12 compute_class_balance(y_train)
#      13 compute_class_balance(y_val)
#      14 compute_class_balance(y_test)
#
# NameError: name 'compute_class_balance' is not defined
